# %% [markdown]
# ##### 14-Feb-2020

# %% [markdown]
# ## Time Series Concept

# %% [markdown]
# 4 Parts of any Time Series data
# 1. Trend - Fluctuations in long duration of time                    - 10 yrs
# (perhaps due to social media influence among others)
# 2. Cyclicity - Fluctuations in long term say like in 5 to 7 years   - 5 yrs
# (due to recession, inflation, politics etc)
# 3. Seasonality - Fluctuations based on Season                       - 1 yr
# (like umbrellas in monsoon, sweaters in winter etc)
# 4. Irregular - Noise data that cannot be explained                  - day to day
# (sudden announcement of trade war)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Two Types of Time Series Model
# 1. Traditional Model
# 2. Auto Regressive Model

# %% [markdown]
# Traditional Model
# 1. Simple Moving Average
# 2. Weighted Moving Average
# 3. Simple Exponential Moving Average

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
import itertools
import warnings
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

plt.style.use('fivethirtyeight')

# %% [markdown]
# For time series data,
# 1. index column should have the time series.
# 2. it should be in datetime format
# 3. resample based on required interval

# %%
df = pd.read_csv('Co2.csv', index_col = 0)
df.head()
# Out:
#               co2
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4

# %%
print(df.shape)
# Out:
# (2284, 1)

# %%
print(df.isnull().sum())
# Out:
# co2    59
# dtype: int64

# %% [markdown]
# ## Indexing with Time Series Data

# %% [markdown]
# We need to make sure that dates are used as as index, which we can do by running the following code.

# %%
print(df.index)
# Out:
# Index(['1958-03-29', '1958-04-05', '1958-04-12', '1958-04-19', '1958-04-26',
#        '1958-05-03', '1958-05-10', '1958-05-17', '1958-05-24', '1958-05-31',
#        ...
#        '2001-10-27', '2001-11-03', '2001-11-10', '2001-11-17', '2001-11-24',
#        '2001-12-01', '2001-12-08', '2001-12-15', '2001-12-22', '2001-12-29'],
#       dtype='object', length=2284)

# %% [markdown]
# Check for dtype:
# The dtype of the index column shoud be datetime[ns] and not float. Lets check the dtype using the info function.

# %%
df.index = pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['1958-03-29', '1958-04-05', '1958-04-12', '1958-04-19',
#                '1958-04-26', '1958-05-03', '1958-05-10', '1958-05-17',
#                '1958-05-24', '1958-05-31',
#                ...
#                '2001-10-27', '2001-11-03', '2001-11-10', '2001-11-17',
#                '2001-11-24', '2001-12-01', '2001-12-08', '2001-12-15',
#                '2001-12-22', '2001-12-29'],
#               dtype='datetime64[ns]', length=2284, freq=None)

# %% [markdown]
# From the above output we see that the dates are in weekly format.
# Weekly data can be tricky to work with.
# Hence it is better to convert it into monthly averages data.
# This can be obtained by using the resampling function.

# %%
y = df.co2.resample("MS").mean()
y.head()
# Out:
# 1958-03-01    316.100000
# 1958-04-01    317.200000
# 1958-05-01    317.433333
# 1958-06-01           NaN
# 1958-07-01    315.625000
# Freq: MS, Name: co2, dtype: float64

# %% [markdown]
# Lets look at the min and max of the data

# %%
y.index.min(), y.index.max()
# Out:
# (Timestamp('1958-03-01 00:00:00', freq='MS'),
#  Timestamp('2001-12-01 00:00:00', freq='MS'))

# %%
print("min = ",y.index.min(), "\nmax = ",y.index.max())
# Out:
# min =  1958-03-01 00:00:00
# max =  2001-12-01 00:00:00

# %% [markdown]
# From the above output, we see that we have data from March 1958 to December 2001.

# %% [markdown]
# Lets see some data manipulation using datetime data.

# %% [markdown]
# 1. Show all data from year 1990 to end

# %%
y["1990":]
# Out:
# 1990-01-01    353.650
# 1990-02-01    354.650
# 1990-03-01    355.480
# 1990-04-01    356.175
# 1990-05-01    357.075
#                ...
# 2001-08-01    369.425
# 2001-09-01    367.880
# 2001-10-01    368.050
# 2001-11-01    369.375
# 2001-12-01    371.020
# Freq: MS, Name: co2, Length: 144, dtype: float64

# %% [markdown]
# 2. Show all data from October 1995 to October 1996

# %%
y["1995-10-01":"1996-10-1"]
# Out:
# 1995-10-01    357.850
# 1995-11-01    359.475
# 1995-12-01    360.700
# 1996-01-01    362.025
# 1996-02-01    363.175
# 1996-03-01    364.060
# 1996-04-01    364.700
# 1996-05-01    365.325
# 1996-06-01    364.880
# 1996-07-01    363.475
# 1996-08-01    361.320
# 1996-09-01    359.400
# 1996-10-01    359.625
# Freq: MS, Name: co2, dtype: float64

# %% [markdown]
# #### Handling missing values in Time-series Data

# %%
y.isnull().sum()
# Out:
# 5

# %%
y_null = y.isnull()
y_null
# Out:
# 1958-03-01    False
# 1958-04-01    False
# 1958-05-01    False
# 1958-06-01     True
# 1958-07-01    False
#               ...
# 2001-08-01    False
# 2001-09-01    False
# 2001-10-01    False
# 2001-11-01    False
# 2001-12-01    False
# Freq: MS, Name: co2, Length: 526, dtype: bool

# %%
y["1964":"1964"]
# Out:
# 1964-01-01    319.400
# 1964-02-01        NaN
# 1964-03-01        NaN
# 1964-04-01        NaN
# 1964-05-01    322.000
# 1964-06-01    321.750
# 1964-07-01    320.300
# 1964-08-01    318.500
# 1964-09-01    316.600
# 1964-10-01    316.960
# 1964-11-01    317.725
# 1964-12-01    318.675
# Freq: MS, Name: co2, dtype: float64

# %% [markdown]
# There are multiple ways in which you can fill the null values.
# 1. Forward filling
# 2. Backward filling
# 3. Linear Interpolation
# 4. Moving Average

# %%
y.head()
# Out:
# 1958-03-01    316.100000
# 1958-04-01    317.200000
# 1958-05-01    317.433333
# 1958-06-01           NaN
# 1958-07-01    315.625000
# Freq: MS, Name: co2, dtype: float64

# %% [markdown]
# Forward filling: Uses previous month's data to fill next record.

# %%
y_f = y.fillna(y.ffill())
y_f.head()
# Out:
# 1958-03-01    316.100000
# 1958-04-01    317.200000
# 1958-05-01    317.433333
# 1958-06-01    317.433333
# 1958-07-01    315.625000
# Freq: MS, Name: co2, dtype: float64

# %% [markdown]
# Bakcward Filling: Uses next months' data to fill previous record.

# %%
y_b = y.fillna(y.bfill())
y_b.head()
# Out:
# 1958-03-01    316.100000
# 1958-04-01    317.200000
# 1958-05-01    317.433333
# 1958-06-01    315.625000
# 1958-07-01    315.625000
# Freq: MS, Name: co2, dtype: float64

# %% [markdown]
# Linear Interpolation: Takes the average of the previous and next record
# If there are multiple missing values in series, it adjusts the imputed values in a linear fashion between the preceeding record and the succeeding record.

# %%
y_inter = y.interpolate()
y_inter.head()
# Out:
# 1958-03-01    316.100000
# 1958-04-01    317.200000
# 1958-05-01    317.433333
# 1958-06-01    316.529167
# 1958-07-01    315.625000
# Freq: MS, Name: co2, dtype: float64

# %% [markdown]
# Rolling: Provides rolling window calculations
# DataFrame.rolling(window, min_periods=1).mean()

# %%
y_3 = y.fillna(y.rolling(12,center = True, min_periods=1).mean())
y_3[70:80]
# Out:
# 1964-01-01    319.400000
# 1964-02-01    318.733333
# 1964-03-01    318.833333
# 1964-04-01    318.883333
# 1964-05-01    322.000000
# 1964-06-01    321.750000
# 1964-07-01    320.300000
# 1964-08-01    318.500000
# 1964-09-01    316.600000
# 1964-10-01    316.960000
# Freq: MS, Name: co2, dtype: float64

# %%
y = y.interpolate()
y.head()
# Out:
# 1958-03-01    316.100000
# 1958-04-01    317.200000
# 1958-05-01    317.433333
# 1958-06-01    316.529167
# 1958-07-01    315.625000
# Freq: MS, Name: co2, dtype: float64

# %% [markdown]
# ### Visualizing Time series Data

# %%
y_3.plot(figsize = (11,7))
plt.xlabel("Date")
plt.ylabel("CO2 Levels")
plt.grid(True)
plt.show();

# %% [markdown]
# ### Time Series Decomposition

# %%
from pylab import rcParams
rcParams["figure.figsize"] = 11,9
decomposition = sm.tsa.seasonal_decompose(y_3, model='additive')
fig = decomposition.plot()
plt.show();

# %% [markdown]
# ### Additive vs Multiplicative Time Series

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Additive Nature Example:
# A restaurant has tied up with a college that is open only on weekdays.
# If a fixed number of students exist, the restaurant will get that many number of orders in addition to its normal customers. This scenario is additive in nature, where demand for food on weekdays adds by the number of students.
# y(demand) = x1(normal demand) + x2(demand on weekdays due to students) + irregular component

# %% [markdown]
# Multiplicative Nature Example:
# Consider the case of another restuarant.
# This restaurants demand has increased due to combination of increase in students over time independent of weekdays or weekends.
# y(demand) = x1(normal demand) * x2(population growth %)

# %% [markdown]
# ### Stationary vs Non-Stationary

# %% [markdown]
# Time Series is considered Sationary when
# 1. Mean is constant
# 2. Variance is constant
# 3. Co-variance is constant

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# White Noise Time Series - When there is no pattern, can't be explained

# %% [markdown]
# Random Walk Time Series - There is trend, but variance is random

# %% [markdown]
# Why is Stationary so important?
# 1. Easier to analyze because statistical properties remain constant over time
# 2. Linear Regression, Autoregression is built on assumption that all variables are independent

# %% [markdown]
# Stationary Tests
# 1. KPSS
# 2. ADF

# %% [markdown]
# How to make it stationary?
# 1. Mean - differentiation
# 2. Variance - smoothing by using box-cox transformation
# 3. Covaraince - ACF

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Auto-Regression
# y = a1 x1 + a2 x2 + a3 x3 + a4 x4 + ..... + error
#
# For time series, the same logic is followed
# y(t) = a1 y(t-1) + a2 y(t-2) + a3 y(t-3) + ..... + error

# %% [markdown]
# ### Time Series Method
# 1. ARIMA - Auto Regressive Integrated Moving average model
# Problem: Does not take care of seasonality or external factors
#
# 2. SARIMA - Seasonal ARIMA
# Problem: Does not take care of external factors
#
# 3. ARIMAX - ARIMA Exogenous
# Problem: Does not take care of Seasonality
#
# 4. SARIMAX - SARIMA Exogenous
# Takes care of both problems

# %% [markdown]
# Auto-Correlation (ACF)
# 1. Partial ACF
# 2. ACF

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For y(t) = a1 y(t-1) + a2 y(t-2) + a3 y(t-3) + ..... + error
# ### PACF
# Lets say we want the effect of y(t-2) on y(t).
# To do so, we have to make 0 all other coefficients.
# It then becomes
# y(t) = a y(t-2) + error
# This is Partical ACF

# %% [markdown]
# Next, how do we take care of the error?
# This is done by gradient boosting techniques.

# %% [markdown]
# ARMA Model
# y(t) = u + a1.s(t-1) + a2.e(t-1)
# s = lag, e = error

# %% [markdown]
# ARIMA Model = ARMA Model + Differentiation integration

# %% [markdown]
# order(1,0,0)
# order(lag, order of differentiation ,error)
# order(PACF, check with ADF , ACF)

# %% [markdown]
# order : iterable
#     The (p,d,q) order of the model for the number of AR parameters,
#     differences, and MA parameters to use.

# %% [markdown]
# ACF:
# correlation of present with its lagged values
# considers trend, seasonality, cyclic, residual
# Hence it's a complete auto-correlation.
#
# PACF:
# correlation of residuals with next lag value
# residuals - what remains after removing the effects explained by earlier lags
# effects - trend, seasonality, cyclic, residual
